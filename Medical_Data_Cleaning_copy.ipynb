# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
med_data=pd.read_excel('/content/drive/MyDrive/data cleaning med data.xlsx')

# %%
med_data.head(30)
# Out:
#     id                       classification code     description  \
# 0    1                                  NaN  NaN       IVD Other
# 1    2                                  NaN  NaN       Class IIB
# 2    3                                  NaN  NaN       Class IIA
# 3    4                                  NaN  NaN       Class IIB
# 4    5                                  NaN  NaN       IVD Other
# 5    6                                  NaN  NaN       IVD Other
# 6    7                                  NaN  NaN       Class IIA
# 7    8                                  NaN  NaN       Class III
# 8    9                                  NaN  NaN       Class IIA
# 9   10                                  NaN  NaN       Class III
# 10  11                                  NaN  NaN             NaN
# 11  12                                  NaN  NaN       IVD Other
# 12  13                                  NaN  NaN       IVD Other
# ...

# %%
dfmedico0=med_data.iloc[:5000]

# %%
dfmedico1=med_data.iloc[5000:10000]

# %%
dfmedico2=med_data.iloc[10000:15000]

# %%
dfmedico3=med_data.iloc[15000:20000]

# %%
dfmedico4=med_data.iloc[20000:25000]

# %%
dfmedico5=med_data.iloc[25000:30000]

# %%
dfmedico6=med_data.iloc[30000:35000]

# %%
dfmedico7=med_data.iloc[35000:40000]

# %%
dfmedico8=med_data.iloc[40000:45000]

# %%
dfmedico9=med_data.iloc[45000:50000]

# %%
dfmedico10=med_data.iloc[50000:55000]

# %%
dfmedico11=med_data.iloc[55000:60000]

# %%
dfmedico12=med_data.iloc[60000:65000]
dfmedico13=med_data.iloc[65000:70000]
dfmedico14=med_data.iloc[70000:75000]
dfmedico15=med_data.iloc[75000:80000]
dfmedico16=med_data.iloc[80000:85000]
dfmedico17=med_data.iloc[85000:90000]
dfmedico18=med_data.iloc[90000:95000]
dfmedico19=med_data.iloc[95000:100000]
dfmedico20=med_data.iloc[100000:105000]
dfmedico21=med_data.iloc[105000:110000]
dfmedico22=med_data.iloc[110000:115000]
dfmedico23=med_data.iloc[115000:]

# %%
dfmedico0['name'] = dfmedico0['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)

# Print the updated dataframe
# Out:
# <ipython-input-18-fb7eb0517741>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico0['name'] = dfmedico0['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)

# %%
dfmedico0.tail(30)
# Out:
#         id                    classification code description distributed_to  \
# 4970  4971                               NaN  NaN         NaN            NaN
# 4971  4972                               NaN  NaN         NaN            NaN
# 4972  4973                               NaN  NaN         NaN            NaN
# 4973  4974                               NaN  NaN         NaN            NaN
# 4974  4975                               NaN  NaN         NaN            NaN
# 4975  4976                               NaN  NaN         NaN            NaN
# 4976  4977                               NaN  NaN         NaN            NaN
# 4977  4978                               NaN  NaN         NaN            NaN
# 4978  4979  Hematology and Pathology Devices  NaN         NaN            NaN
# 4979  4980                               NaN  NaN         NaN            NaN
# 4980  4981                               NaN  NaN         NaN            NaN
# ...

# %%
dfmedico0['number'] = dfmedico0['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-20-54b009e5606e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico0['number'] = dfmedico0['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)

# %%
dfmedico0['description'] = dfmedico0['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-21-3f3a39eb631e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico0['description'] = dfmedico0['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)

# %%
dfmedico0['classification'] = dfmedico0['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-22-44988af90e76>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico0['classification'] = dfmedico0['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)

# %%
dfmedico0
# Out:
#         id classification code description distributed_to implanted  \
# 0        1            NaN  NaN   IVD Other            NaN       NaN
# 1        2            NaN  NaN   Class IIB            NaN       NaN
# 2        3            NaN  NaN   Class IIA            NaN       NaN
# 3        4            NaN  NaN   Class IIB            NaN       NaN
# 4        5            NaN  NaN   IVD Other            NaN       NaN
# ...    ...            ...  ...         ...            ...       ...
# 4995  4996            NaN  NaN         NaN            NaN       NaN
# 4996  4997            NaN  NaN         NaN            NaN       NaN
# 4997  4998            NaN  NaN         NaN            NaN       NaN
# 4998  4999            NaN  NaN         NaN            NaN       NaN
# 4999  5000            NaN  NaN         NaN            NaN       NaN
#
#                                                    name  \
# 0                             Cell-Dyn Emerald Cleanser
# ...

# %%
dfmedico1['name'] = dfmedico1['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-24-6abc08d8736d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico1['name'] = dfmedico1['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)

# %%
dfmedico1['number'] = dfmedico1['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico1['description'] = dfmedico1['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico1['classification'] = dfmedico1['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-25-6547c05c1b9e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico1['number'] = dfmedico1['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-25-6547c05c1b9e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico1['description'] = dfmedico1['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-25-6547c05c1b9e>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico1.head(30)
# Out:
#         id classification code description distributed_to implanted  \
# 5000  5001            NaN  NaN         NaN            NaN       NaN
# 5001  5002            NaN  NaN         NaN            NaN       NaN
# 5002  5003            NaN  NaN         NaN            NaN       NaN
# 5003  5004            NaN  NaN         NaN            NaN       NaN
# 5004  5005            NaN  NaN         NaN            NaN       NaN
# 5005  5006            NaN  NaN         NaN            NaN       NaN
# 5006  5007            NaN  NaN         NaN            NaN       NaN
# 5007  5008            NaN  NaN         NaN            NaN       NaN
# 5008  5009            NaN  NaN         NaN            NaN       NaN
# 5009  5010            NaN  NaN         NaN            NaN       NaN
# 5010  5011            NaN  NaN         NaN            NaN       NaN
# 5011  5012            NaN  NaN         NaN            NaN       NaN
# 5012  5013            NaN  NaN         NaN            NaN       NaN
# ...

# %%
dfmedico2['name'] = dfmedico2['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico2['number'] = dfmedico2['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico2['description'] = dfmedico2['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico2['classification'] = dfmedico2['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-27-efa0c393b5c2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico2['name'] = dfmedico2['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-27-efa0c393b5c2>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico2['number'] = dfmedico2['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-27-efa0c393b5c2>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico2.head(30)
# Out:
#           id classification code              description distributed_to  \
# 10000  10001            NaN  NaN  in-vitro_medical_device            NaN
# 10001  10002            NaN  NaN           medical_device            NaN
# 10002  10003            NaN  NaN  in-vitro_medical_device            NaN
# 10003  10004            NaN  NaN           medical_device            NaN
# 10004  10005            NaN  NaN  in-vitro_medical_device            NaN
# 10005  10006            NaN  NaN  in-vitro_medical_device            NaN
# 10006  10007            NaN  NaN           medical_device            NaN
# 10007  10008            NaN  NaN           medical_device            NaN
# 10008  10009            NaN  NaN           medical_device            NaN
# 10009  10010            NaN  NaN           medical_device            NaN
# 10010  10011            NaN  NaN  in-vitro_medical_device            NaN
# 10011  10012            NaN  NaN           medical_device            NaN
# ...

# %%
dfmedico3['name'] = dfmedico3['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico3['number'] = dfmedico3['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico3['description'] = dfmedico3['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico3['classification'] = dfmedico3['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-29-e81e8a0f7dba>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico3['name'] = dfmedico3['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-29-e81e8a0f7dba>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico3['number'] = dfmedico3['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-29-e81e8a0f7dba>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico4['name'] = dfmedico4['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico4['number'] = dfmedico4['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico4['description'] = dfmedico4['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico4['classification'] = dfmedico4['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-30-cf898f492792>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico4['name'] = dfmedico4['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-30-cf898f492792>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico4['number'] = dfmedico4['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-30-cf898f492792>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico5['name'] = dfmedico5['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico5['number'] = dfmedico5['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico5['description'] = dfmedico5['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico5['classification'] = dfmedico5['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-31-f0ce661e89d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico5['name'] = dfmedico5['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-31-f0ce661e89d0>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico5['number'] = dfmedico5['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-31-f0ce661e89d0>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico6['name'] = dfmedico6['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico6['number'] = dfmedico6['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico6['description'] = dfmedico6['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico6['classification'] = dfmedico6['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-32-0f3ea956cb23>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico6['name'] = dfmedico6['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-32-0f3ea956cb23>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico6['number'] = dfmedico6['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-32-0f3ea956cb23>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico7['name'] = dfmedico7['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico7['number'] = dfmedico7['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico7['description'] = dfmedico7['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico7['classification'] = dfmedico7['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-33-47c4277de2ce>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico7['name'] = dfmedico7['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-33-47c4277de2ce>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico7['number'] = dfmedico7['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-33-47c4277de2ce>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico8['name'] = dfmedico8['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico8['number'] = dfmedico8['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico8['description'] = dfmedico8['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico8['classification'] = dfmedico8['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-34-65cfee5041cd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico8['name'] = dfmedico8['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-34-65cfee5041cd>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico8['number'] = dfmedico8['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-34-65cfee5041cd>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico9['name'] = dfmedico9['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico9['number'] = dfmedico9['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico9['description'] = dfmedico9['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico9['classification'] = dfmedico9['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-35-2aaefe9821a9>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico9['name'] = dfmedico9['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-35-2aaefe9821a9>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico9['number'] = dfmedico9['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-35-2aaefe9821a9>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico10['name'] = dfmedico10['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico10['number'] = dfmedico10['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico10['description'] = dfmedico10['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico10['classification'] = dfmedico10['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-36-f6fe75280d05>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico10['name'] = dfmedico10['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-36-f6fe75280d05>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico10['number'] = dfmedico10['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-36-f6fe75280d05>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico10.head(30)
# Out:
#           id                                     classification code  \
# 50000  49959          General Hospital and Personal Use Devices  FSA
# 50001  49960          General Hospital and Personal Use Devices  FSA
# 50002  49961          General Hospital and Personal Use Devices  FSA
# 50003  49962                               Neurological Devices  GWQ
# 50004  49963                                  Radiology Devices  JAK
# 50005  49964                                  Radiology Devices  EAP
# 50006  49965                                  Radiology Devices  LMB
# 50007  49966                                  Radiology Devices  LNH
# 50008  49967                                  Radiology Devices  LMD
# 50009  49968  Clinical Chemistry and Clinical Toxicology Dev...  DIO
# 50010  49969                General and Plastic Surgery Devices  GFA
# 50011  49970  Clinical Chemistry and Clinical Toxicology Dev...  JJE
# 50012  49971                             Anesthesiology Devices  CBK
# ...

# %%
dfmedico11['name'] = dfmedico11['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico11['number'] = dfmedico11['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico11['description'] = dfmedico11['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico11['classification'] = dfmedico11['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-38-7cd9db28e4f5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico11['name'] = dfmedico11['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-38-7cd9db28e4f5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico11['number'] = dfmedico11['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-38-7cd9db28e4f5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico12['name'] = dfmedico12['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico12['number'] = dfmedico12['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico12['description'] = dfmedico12['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico12['classification'] = dfmedico12['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-39-bb5c2175930f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico12['name'] = dfmedico12['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-39-bb5c2175930f>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico12['number'] = dfmedico12['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-39-bb5c2175930f>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico13['name'] = dfmedico13['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico13['number'] = dfmedico13['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico13['description'] = dfmedico13['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico13['classification'] = dfmedico13['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-40-8ef1f4b64653>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico13['name'] = dfmedico13['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-40-8ef1f4b64653>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico13['number'] = dfmedico13['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-40-8ef1f4b64653>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico14['name'] = dfmedico14['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico14['number'] = dfmedico14['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico14['description'] = dfmedico14['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico14['classification'] = dfmedico14['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-41-3021cc51c069>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico14['name'] = dfmedico14['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-41-3021cc51c069>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico14['number'] = dfmedico14['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-41-3021cc51c069>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico15['name'] = dfmedico15['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico15['number'] = dfmedico15['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico15['description'] = dfmedico15['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico15['classification'] = dfmedico15['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-42-4adffa67b439>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico15['name'] = dfmedico15['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-42-4adffa67b439>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico15['number'] = dfmedico15['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-42-4adffa67b439>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico16['name'] = dfmedico16['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico16['number'] = dfmedico16['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico16['description'] = dfmedico16['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico16['classification'] = dfmedico16['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-43-1be585a7f938>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico16['name'] = dfmedico16['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-43-1be585a7f938>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico16['number'] = dfmedico16['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-43-1be585a7f938>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico17['name'] = dfmedico17['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico17['number'] = dfmedico17['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico17['description'] = dfmedico17['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico17['classification'] = dfmedico17['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-44-c0aa61993e53>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico17['name'] = dfmedico17['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-44-c0aa61993e53>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico17['number'] = dfmedico17['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-44-c0aa61993e53>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico18['name'] = dfmedico18['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico18['number'] = dfmedico18['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico18['description'] = dfmedico18['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico18['classification'] = dfmedico18['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-45-fc32ca0e751d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico18['name'] = dfmedico18['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-45-fc32ca0e751d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico18['number'] = dfmedico18['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-45-fc32ca0e751d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico19['name'] = dfmedico19['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico19['number'] = dfmedico19['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico19['description'] = dfmedico19['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico19['classification'] = dfmedico19['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-46-0a4eee44abbb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico19['name'] = dfmedico19['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-46-0a4eee44abbb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico19['number'] = dfmedico19['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-46-0a4eee44abbb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico20['name'] = dfmedico20['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico20['number'] = dfmedico20['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico20['description'] = dfmedico20['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico20['classification'] = dfmedico20['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-47-eee3cfb25f4c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico20['name'] = dfmedico20['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-47-eee3cfb25f4c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico20['number'] = dfmedico20['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-47-eee3cfb25f4c>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico21['name'] = dfmedico21['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico21['number'] = dfmedico21['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico21['description'] = dfmedico21['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico21['classification'] = dfmedico21['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-48-e3982c72e13d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico21['name'] = dfmedico21['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-48-e3982c72e13d>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico21['number'] = dfmedico21['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-48-e3982c72e13d>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico22['name'] = dfmedico22['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico22['number'] = dfmedico22['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico22['description'] = dfmedico22['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico22['classification'] = dfmedico22['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-49-7621b0751afb>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico22['name'] = dfmedico22['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-49-7621b0751afb>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico22['number'] = dfmedico22['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-49-7621b0751afb>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
dfmedico23['name'] = dfmedico23['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico23['number'] = dfmedico23['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico23['description'] = dfmedico23['description'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
dfmedico23['classification'] = dfmedico23['classification'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# Out:
# <ipython-input-50-05d37aa151ea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico23['name'] = dfmedico23['name'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-50-05d37aa151ea>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dfmedico23['number'] = dfmedico23['number'].str.replace('[!#$Ââ„¢€Ã³·Î£]', '', regex=True)
# <ipython-input-50-05d37aa151ea>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
comp_med=pd.read_excel('/content/drive/MyDrive/med data companies excel.xlsx')

# %%
comp_med.rename(columns={'id':'manufacturer_id'},inplace=True)

# %%
comp_med.head(40)
# Out:
#     manufacturer_id address  \
# 0                 1     NaN
# 1                 2     NaN
# 2                 3     NaN
# 3                 4     NaN
# 4                 5     NaN
# 5                 6     NaN
# 6                 7     NaN
# 7                 8     NaN
# 8                 9     NaN
# 9                10     NaN
# 10               11     NaN
# 11               12     NaN
# 12               13     NaN
# 13               14     NaN
# 14               15     NaN
# 15               16     NaN
# 16               17     NaN
# 17               18     NaN
# 18               19     NaN
# 19               20     NaN
# 20               21     NaN
# 21               22     NaN
# 22               23     NaN
# 23               24     NaN
# 24               25     NaN
# 25               26     NaN
# 26               27     NaN
# 27               28     NaN
# 28               29     NaN
# 29               30     NaN
# 30               31     NaN
# 31               32     NaN
# ...

# %%
comp_med['name'] = comp_med['name'].str.replace('[!#$Ââ„¢€Ã³·Î£œÄž]', '', regex=True)
comp_med['parent_company'] = comp_med['parent_company'].str.replace('[!#$Ââ„¢€Ã³·Î£œÄž]', '', regex=True)
comp_med['comment'] = comp_med['comment'].str.replace('[!#$Ââ„¢€Ã³·Î£œÄž]', '', regex=True)

# %%
pattern='[°]'
kadali=comp_med['name'].str.contains(pattern, regex=True)

# %%
i=0
for x in kadali:
  if x==True:
    print(x)
    print(i)
  i=i+1
# Out:
# True
# 3
# True
# 4
# True
# 22187
# True
# 22290
# True
# 22293
# True
# 26776

# %%
comp_med['name'][3]='ANADOLU TIP TEKNO ÜRETİM PAZ İTH İHRTİC SAN AŞ'
# Out:
# <ipython-input-57-078bfbedbe85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_med['name'][3]='ANADOLU TIP TEKNO ÜRETİM PAZ İTH İHRTİC SAN AŞ'

# %%
comp_med['name'][4]='ARCHEM SAĞLIK SANAYİ VE TİCARET A.Ş.'
# Out:
# <ipython-input-58-9eb2a4351bfc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_med['name'][4]='ARCHEM SAĞLIK SANAYİ VE TİCARET A.Ş.'

# %%
comp_med['name'][22290]='Fabrica de Artefatos de Latex Blowtex, Ltda Estrada Municipal Dr. Irineu De Resende, Le 550/570 Aluminio, SP 18125-000 Brazil'
# Out:
# <ipython-input-59-77d8ef10312b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_med['name'][22290]='Fabrica de Artefatos de Latex Blowtex, Ltda Estrada Municipal Dr. Irineu De Resende, Le 550/570 Aluminio, SP 18125-000 Brazil'

# %%
comp_med['name'][22293]='Biomecânica Ind e Com de Produtos Ortopédicos Ltda. Address: Rua Luiz Pengo, 145  1st Industrial District, Phone: (14) 2104-7900, City: Jaú, CEP 17212-811, State: 82'
# Out:
# <ipython-input-60-19b03251f5d0>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_med['name'][22293]='Biomecânica Ind e Com de Produtos Ortopédicos Ltda. Address: Rua Luiz Pengo, 145  1st Industrial District, Phone: (14) 2104-7900, City: Jaú, CEP 17212-811, State: 82'

# %%
comp_med['name'][26776]='ABC TIP SAĞLIK SPOR MALZ. TEKS. TURZ. İNŞ. SAN. TİC. LTD. ŞTİ.,Turkey'
# Out:
# <ipython-input-61-a0bf00e60a85>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   comp_med['name'][26776]='ABC TIP SAĞLIK SPOR MALZ. TEKS. TURZ. İNŞ. SAN. TİC. LTD. ŞTİ.,Turkey'

# %%
pattern='[°]'
amba=comp_med['parent_company'].str.contains(pattern, regex=True)

# %%
j=0
for x in amba:
  if x==True:
    print(x)
    print(j)
  j=j+1

# %%
merged_med0=pd.merge(dfmedico0,comp_med,on='manufacturer_id')

# %%
merged_med0.head(20)
# Out:
#     id                       classification code     description  \
# 0    1                                  NaN  NaN       IVD Other
# 1    2                                  NaN  NaN       Class IIB
# 2    3                                  NaN  NaN       Class IIA
# 3    4                                  NaN  NaN       Class IIB
# 4    5                                  NaN  NaN       IVD Other
# 5    6                                  NaN  NaN       IVD Other
# 6    7                                  NaN  NaN       Class IIA
# 7    8                                  NaN  NaN       Class III
# 8    9                                  NaN  NaN       Class IIA
# 9   10                                  NaN  NaN       Class III
# 10  11                                  NaN  NaN             NaN
# 11  12                                  NaN  NaN       IVD Other
# 12  13                                  NaN  NaN       IVD Other
# ...

# %%
merged_med1=pd.merge(dfmedico1,comp_med,on='manufacturer_id')

# %%
merged_med1.head(23)
# Out:
#       id                                     classification code description  \
# 0   5001                                                NaN  NaN         NaN
# 1   5027                                                NaN  NaN         NaN
# 2   5002                                                NaN  NaN         NaN
# 3   5025                                                NaN  NaN         NaN
# 4   5026                                                NaN  NaN         NaN
# 5   5048  Clinical Chemistry and Clinical Toxicology Dev...  NaN         NaN
# 6   5003                                                NaN  NaN         NaN
# 7   5004                                                NaN  NaN         NaN
# 8   5005                                                NaN  NaN         NaN
# 9   5006                                                NaN  NaN         NaN
# 10  5007                                                NaN  NaN         NaN
# ...

# %%
merged_med2=pd.merge(dfmedico2,comp_med,on='manufacturer_id')
merged_med3=pd.merge(dfmedico3,comp_med,on='manufacturer_id')
merged_med4=pd.merge(dfmedico4,comp_med,on='manufacturer_id')
merged_med5=pd.merge(dfmedico5,comp_med,on='manufacturer_id')
merged_med6=pd.merge(dfmedico6,comp_med,on='manufacturer_id')
merged_med7=pd.merge(dfmedico7,comp_med,on='manufacturer_id')
merged_med8=pd.merge(dfmedico8,comp_med,on='manufacturer_id')
merged_med9=pd.merge(dfmedico9,comp_med,on='manufacturer_id')
merged_med10=pd.merge(dfmedico10,comp_med,on='manufacturer_id')
merged_med11=pd.merge(dfmedico11,comp_med,on='manufacturer_id')
merged_med12=pd.merge(dfmedico12,comp_med,on='manufacturer_id')
merged_med13=pd.merge(dfmedico13,comp_med,on='manufacturer_id')
merged_med14=pd.merge(dfmedico14,comp_med,on='manufacturer_id')
merged_med15=pd.merge(dfmedico15,comp_med,on='manufacturer_id')
merged_med16=pd.merge(dfmedico16,comp_med,on='manufacturer_id')
merged_med17=pd.merge(dfmedico17,comp_med,on='manufacturer_id')
merged_med18=pd.merge(dfmedico18,comp_med,on='manufacturer_id')
merged_med19=pd.merge(dfmedico19,comp_med,on='manufacturer_id')
merged_med20=pd.merge(dfmedico20,comp_med,on='manufacturer_id')
merged_med21=pd.merge(dfmedico21,comp_med,on='manufacturer_id')
merged_med22=pd.merge(dfmedico22,comp_med,on='manufacturer_id')
merged_med23=pd.merge(dfmedico23,comp_med,on='manufacturer_id')

# %%
concatenated_df=pd.concat([merged_med0,merged_med1,merged_med2,merged_med3,merged_med4,merged_med5,merged_med6,merged_med7,merged_med8,merged_med9,merged_med10,merged_med11,merged_med12,merged_med13,merged_med14,merged_med15,merged_med16,merged_med17,merged_med18,merged_med19,merged_med20,merged_med21,merged_med22,merged_med23],axis=0)

# %%
concatenated_df.drop(['code'],axis=1,inplace=True)

# %%
concatenated_df.drop(['implanted'],axis=1,inplace=True)

# %%
concatenated_df.drop(['distributed_to'],axis=1,inplace=True)

# %%
concatenated_df.drop(['quantity_in_commerce'],axis=1,inplace=True)

# %%
concatenated_df.drop(['risk_class'],axis=1,inplace=True)

# %%
concatenated_df.drop(['representative'],axis=1,inplace=True)

# %%
concatenated_df.drop(['created_at_y'],axis=1,inplace=True)

# %%
concatenated_df.drop(['updated_at_y'],axis=1,inplace=True)

# %%
concatenated_df.drop(['created_at_x'],axis=1,inplace=True)

# %%
concatenated_df.drop(['updated_at_x'],axis=1,inplace=True)

# %%
concatenated_df.drop(concatenated_df.columns[10:2073],axis=1,inplace=True)

# %%
concatenated_df.isna().sum()
# Out:
# id                      0
# classification      82648
# description         28657
# name_x                 34
# number              55172
# slug_x                  0
# country                 1
# manufacturer_id         0
# Unnamed: 15        118124
# Unnamed: 16        118124
# address             70779
# comment            103813
# name_y               2416
# parent_company      19454
# slug_y                  0
# source                  1
# dtype: int64

# %%
concatenated_df.to_excel('Medical devices, companies data, etc.xlsx')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-81-a1ff655986dc> in <cell line: 1>()
# ----> 1 concatenated_df.to_excel('Medical devices, companies data, etc.xlsx')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# ...
